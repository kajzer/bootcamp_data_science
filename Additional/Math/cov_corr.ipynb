# %% [markdown]
# # Covariance and Correlation

# %% [markdown]
# Covariance measures how two variances vary in tandem from their means.

# %%
# %matplotlib inline

import numpy as np
from pylab import *

def de_mean(x):
    xmean = mean(x)
    return [xi - xmean for xi in x]

def covariance(x,y):
    n = len(x)
    return dot(de_mean(x), de_mean(y))/(n-1)

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

scatter(pageSpeeds, purchaseAmount)

covariance(pageSpeeds, purchaseAmount)
# Out:
# 0.18344237003654124

# %% [markdown]
# Make fabricated amounts an actual function of page speed

# %%
purchaseAmount = np.random.normal(50.0, 10.0, 1000)/pageSpeeds

scatter(pageSpeeds, purchaseAmount)

covariance(pageSpeeds, purchaseAmount)
# Out:
# -18.18349277412582

# %%
def correlation(x,y):
    stddevx = x.std()
    stddevy = y.std()
    return covariance(x,y) / stddevx / stddevy

correlation(pageSpeeds, purchaseAmount)
# Out:
# -0.16816960576328138

# %% [markdown]
# The numpy way

# %%
np.corrcoef(pageSpeeds, purchaseAmount)
# Out:
# array([[ 1.        , -0.16800144],
#        [-0.16800144,  1.        ]])

# %% [markdown]
# Forcing correlation

# %%
purchaseAmount = 100 - pageSpeeds * 3

scatter(pageSpeeds, purchaseAmount)

correlation(pageSpeeds, purchaseAmount)
# Out:
# -1.001001001001001
